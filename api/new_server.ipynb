# %%
# %pip install flask_cors

# %%
import pandas as pd
import numpy as np

from flask import Flask, request, jsonify
from flask_cors import CORS

import json
import logging

from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import StandardScaler, MinMaxScaler

app = Flask(__name__)
CORS(app)
logging.basicConfig(level=logging.DEBUG)

valData = pd.read_csv('./newData.csv').drop(columns=['Unnamed: 0'])
tsdf = pd.read_csv('./timeSeriesVal.csv').drop(columns=['Unnamed: 0'])

def pre_process(df, ranges):
    df['commission_mean'] = np.mean(df['commission'])
    
    def within_range(value, min_val, max_val, num):
        return 1 if min_val <= value <= max_val else num

    for column, (min_val, max_val) in ranges.items():
            if column in df.columns:
                if column == 'commission' or column == 'jailed_ratio':
                    df[column] = df[column].apply(lambda x: x * within_range(x, min_val, max_val, 1))
                elif column == 'missblock':
                    df[column] = df[column].apply(lambda x: x * within_range(x, min_val, max_val, max_val))
                else:
                    df[column] = df[column].apply(lambda x: x * within_range(x, min_val, max_val, 0))

    df['commission_rank'] = df['commission'].rank(ascending=False)
    scaler_0_1 = MinMaxScaler(feature_range=(0, 1))
    
    # df['missblock_rank'] = df['missblock'].rank(ascending=False)
    df['missblock_scaled'] = scaler_0_1.fit_transform(df['missblock'].values.reshape(-1, 1)).flatten()
    df['commission_variance_log'] = np.log1p(df['commission_variance'])
    df['commission_variance_scaled'] = scaler_0_1.fit_transform(df['commission_variance_log'].values.reshape(-1, 1)).flatten()
    df['asset_value_log'] = np.log1p(df['asset_value'])
    # df['asset_value_rank'] = df['asset_value'].rank(ascending=False)
    df['asset_value_scaled'] = scaler_0_1.fit_transform(df['asset_value_log'].values.reshape(-1, 1)).flatten()
    df['asset_variance_log'] = np.log1p(np.sqrt(df['asset_variance']))
    df['asset_variance_scaled'] = scaler_0_1.fit_transform(df['asset_variance_log'].values.reshape(-1, 1)).flatten()

    df['delegator_log'] = np.log1p(df['delegator'])
    max_rank = df['rank'].max()+1
    df['rank'] = df['rank'].apply(lambda x: max_rank if x == 0 else x)

    return df


def weightScore(chainScore, weight):
    chainScore['contribution_score'] = chainScore['contribution_score'] * weight[0] / sum(weight)
    chainScore['stability_score'] = chainScore['stability_score'] * weight[1] / sum(weight)
    chainScore['popularity_score'] = chainScore['popularity_score'] * weight[2] / sum(weight)
    chainScore['commission_score'] = chainScore['commission_score'] * weight[3] / sum(weight)
    chainScore['period_score'] = chainScore['period_score'] * weight[4] / sum(weight)
    chainScore['total_score'] = chainScore['contribution_score'] + chainScore['stability_score'] + chainScore['popularity_score'] + chainScore['commission_score'] + chainScore['period_score']

    return chainScore


def cal_score(df, weight):
    scaler_0_100 = MinMaxScaler(feature_range=(0, 100))
    score = df[['chain', 'voter']]

    # Contribution
    score['contribution_score'] = df['p_participation'] + df['p_passed'] + df['p_matchproposal']
    score['contribution_score'] = scaler_0_100.fit_transform(score[['contribution_score']])

    # Stability
    score['stability_score'] = df['asset_value_scaled'] * (1 - df['asset_variance_scaled']) - df['missblock_scaled'] - df['jailed_ratio'] - df['commission_variance_scaled']
    score['stability_score'] = scaler_0_100.fit_transform(score[['stability_score']])

    # Popularity
    score['popularity_score'] = df['delegator_log'] + 1 / (df['rank'])
    score['popularity_score'] = scaler_0_100.fit_transform(score[['popularity_score']])

    # Commission
    score['commission_score'] = 1 - (df['commission'] / df['commission_mean']) + (df['commission_rank'] / len(df) * 100)
    score['commission_score'] = scaler_0_100.fit_transform(score[['commission_score']])

    # Period
    score['period_score'] = df['day']
    score['period_score'] = scaler_0_100.fit_transform(score[['period_score']])

    return weightScore(score, weight)

def cal_final_score(in_score, out_score, ratio):
    out_score = out_score.drop_duplicates(subset=['voter'])
    in_score = in_score.drop_duplicates(subset=['voter'])
    score = in_score[['chain', 'voter', 'in_score']]
    score = score.merge(out_score[['voter', 'out_score']], how='left', on='voter')
    score['final_score'] = score['in_score'] * ratio[0] + score['out_score'] * ratio[1]
    
    return score

def calculate_angles(features):
    num_features = len(features)
    angles = {}
    for i, feature in enumerate(features):
        angles[feature] = (2 * np.pi * i) / num_features
    return angles

def calculate_position(row, angles):
    x = 0
    y = 0
    total_score = sum(row)

    for feature, score in row.items():
        angle = angles[feature]
        x += np.cos(angle) * score
        y += np.sin(angle) * score

    x /= total_score
    y /= total_score

    return x, y

def calculate_point_angle(x, y):
    return np.arctan2(y, x)

features = ["contribution_score", "stability_score", "popularity_score", "commission_score", "period_score"]
angles = calculate_angles(features)
def calculate_degrees(row):
    scores = row[features]
    x, y = calculate_position(scores, angles)
    point_angle = calculate_point_angle(x, y)
    point_angle_degrees = np.degrees(point_angle)
    if point_angle_degrees < 0:
        point_angle_degrees += 360
    return point_angle_degrees


@app.route('/')
def home():
    return jsonify(message="Proof of Validator")


@app.route('/getHist', methods=['POST'])
def getHist():
    try:
        data = request.get_json()

        chain = data['chain']
        chainData = valData[valData['chain']==chain]
        
        participation = sorted([d for d in chainData['p_participation']])
        passed = sorted([d for d in chainData['p_passed']])
        match = sorted([d for d in chainData['p_matchproposal']])
        missblock = sorted([d for d in chainData['missblock']])
        jailed_ratio = sorted([d for d in chainData['jailed_ratio']])
        asset_value = sorted([d for d in chainData['asset_value']])
        delegator = sorted([d for d in chainData['delegator']])
        rank = sorted([d for d in chainData['rank']])
        commission = sorted([d for d in chainData['commission']])
        day = sorted([d for d in chainData['day']])

        combined_json = {
            "participation": participation,
            "passed": passed,
            "match": match,
            "missblock": missblock,
            "jailed_ratio": jailed_ratio,
            "asset_value": asset_value,
            "delegator": delegator,
            "rank": rank,
            "commission": commission,
            "day": day
        }

        return jsonify(combined_json), 200

    except Exception as e:
        print(f"An error occurred: {e}")
        return jsonify({"error": "Internal Server Error"}), 500

    
@app.route('/getSimilarity', methods=['POST'])
def getSimilarity():
    try:
        data = request.get_json()
        chain = data['chain']
        voter = data['voter']
        weight = data['weight']
        inout_ratio = data['inout_ratio']

        participation = data['p_participation']
        passed = data['p_passed']
        match = data['p_match']
        missblock = data['missblock']
        jailed_ratio = data['jailed_ratio']
        asset_value = data['asset_value']
        delegator = data['delegator']
        rank = data['rank']
        commission = data['commission']
        day = data['day']
        selected = data['selected']

        ranges = {
            "p_participation": participation,
            "p_passed": passed,
            "p_matchproposal": match,
            "missblock": missblock,
            "jailed_ratio": jailed_ratio,
            "asset_value": asset_value,
            "delegator": delegator,
            "rank": rank,
            "commission": commission,
            "day": day
        }

        chain_data = valData[valData['chain'] == chain]
        voters = pd.DataFrame([v for v in chain_data['voter']]).rename(columns={0: 'voter'})
        val_data = valData[valData['voter'].isin(voters['voter'])]

        # 데이터 전처리
        in_data = pre_process(chain_data, ranges)
        out_data = pre_process(val_data, ranges)

        # 점수 계산
        in_score = cal_score(in_data, weight).rename(columns={'total_score': 'in_score'})
        out_score = cal_score(out_data, weight).merge(out_data[['chain', 'voter', 'proportion_av']], how='left', on=['chain', 'voter'])
        out_score['out_score'] = out_score['total_score']*out_score['proportion_av']
        out_score = out_score[['voter', 'out_score']].groupby('voter').sum().reset_index(drop=False)
        fin_score = cal_final_score(in_score, out_score, inout_ratio).sort_values(by='final_score', ascending=False).reset_index(drop=True)

        # 유사도 계산
        similar_data = in_score.drop(columns=['in_score']).merge(fin_score[['chain', 'voter', 'final_score']], how='left', on=['chain', 'voter']).sort_values(by='final_score', ascending=False).reset_index(drop=True)
        mrg_data = val_data[['chain', 'voter', 'p_participation', 'p_passed', 'p_matchproposal', 'missblock', 'jailed_ratio', 'asset_value', 'commission', 'rank', 'delegator', 'day']]
        similar_data = similar_data.merge(mrg_data, how='left', on=['chain', 'voter'])
        
        similar_feature = similar_data.copy()
        similar_feature = similar_feature.drop(columns=['chain', 'voter'])

        scaler = StandardScaler()
        similar_feature_scaled = scaler.fit_transform(similar_feature)
        similarity_matrix = cosine_similarity(similar_feature_scaled)
        similarity_df = pd.DataFrame(similarity_matrix, index=similar_data['voter'], columns=similar_data['voter'])

        if selected:
            sorted_similarities = similarity_df[voter].sort_values(ascending=False)
        else:
            sorted_similarities = similarity_df[fin_score['voter'].iloc[0]].sort_values(ascending=False)
        sorted_voters = sorted_similarities.sort_values(ascending=False).index
        sorted_similarity_df = similarity_df.loc[sorted_voters, sorted_voters]

        # 반환값 추출
        if selected:
            result_data = pd.DataFrame(sorted_similarity_df.iloc[0]).reset_index(drop=False).rename(columns={voter: 'similarity'})
        else:
            result_data = pd.DataFrame(sorted_similarity_df.iloc[0]).reset_index(drop=False).rename(columns={fin_score['voter'].iloc[0]: 'similarity'})
        result_data = result_data.merge(in_score, how='left', on=['voter']).drop(columns=['chain', 'in_score']).merge(fin_score, how='left', on=['voter']).drop(columns=['chain', 'in_score', 'out_score'])
        result_data['degree'] = result_data.apply(calculate_degrees, axis=1)
        result_data = result_data.to_json(orient='records')

        return result_data, 200

    except Exception as e:
        print(f"An error occurred: {e}")
        return jsonify({"error": "Internal Server Error"}), 500


@app.route('/getSimilarInfo', methods=['POST'])
def getSimilarInfo():
    try:
        data = request.get_json()
        chain = data['chain']
        voter = data['voter']
        weight = data['weight']
        inout_ratio = data['inout_ratio']

        participation = data['p_participation']
        passed = data['p_passed']
        match = data['p_match']
        missblock = data['missblock']
        jailed_ratio = data['jailed_ratio']
        asset_value = data['asset_value']
        delegator = data['delegator']
        rank = data['rank']
        commission = data['commission']
        day = data['day']
        selected = data['selected']

        ranges = {
            "p_participation": participation,
            "p_passed": passed,
            "p_matchproposal": match,
            "missblock": missblock,
            "jailed_ratio": jailed_ratio,
            "asset_value": asset_value,
            "delegator": delegator,
            "rank": rank,
            "commission": commission,
            "day": day
        }

        chain_data = valData[valData['chain'] == chain]
        voters = pd.DataFrame([v for v in chain_data['voter']]).rename(columns={0: 'voter'})
        val_data = valData[valData['voter'].isin(voters['voter'])]

        # 데이터 전처리
        in_data = pre_process(chain_data, ranges)
        out_data = pre_process(val_data, ranges)

        # 점수 계산
        in_score = cal_score(in_data, weight).rename(columns={'total_score': 'in_score'})
        out_score = cal_score(out_data, weight).merge(out_data[['chain', 'voter', 'proportion_av']], how='left', on=['chain', 'voter'])
        out_score['out_score'] = out_score['total_score']*out_score['proportion_av']
        out_score = out_score[['voter', 'out_score']].groupby('voter').sum().reset_index(drop=False)
        fin_score = cal_final_score(in_score, out_score, inout_ratio).sort_values(by='final_score', ascending=False).reset_index(drop=True)

        # 새로운 랭크 계산
        rank_data = valData[valData['chain']==chain].merge(fin_score, how='left', on=['chain', 'voter'])
        rank_data = rank_data[['voter', 'final_score']]
        rank_data = rank_data.sort_values(by='final_score', ascending=False).reset_index(drop=True).reset_index(drop=False)
        rank_data['index'] = rank_data['index']+1

        # 유사도 계산
        similar_data = in_score.drop(columns=['in_score']).merge(fin_score[['chain', 'voter', 'final_score']], how='left', on=['chain', 'voter']).sort_values(by='final_score', ascending=False).reset_index(drop=True)
        mrg_data = val_data[['chain', 'voter', 'p_participation', 'p_passed', 'p_matchproposal', 'missblock', 'jailed_ratio', 'asset_value', 'commission', 'rank', 'delegator', 'day']]
        similar_data = similar_data.merge(mrg_data, how='left', on=['chain', 'voter'])

        similar_feature = similar_data.copy()
        similar_feature = similar_feature.drop(columns=['chain', 'voter'])

        scaler = StandardScaler()
        similar_feature_scaled = scaler.fit_transform(similar_feature)
        similarity_matrix = cosine_similarity(similar_feature_scaled)
        similarity_df = pd.DataFrame(similarity_matrix, index=similar_data['voter'], columns=similar_data['voter'])
        
        # 유사한 검증인 추출
        if selected:
            sorted_similarities = similarity_df[voter].sort_values(ascending=False)
        else:
            sorted_similarities = similarity_df[fin_score['voter'].iloc[0]].sort_values(ascending=False)
        top_6_voters = sorted_similarities.head(6)
        filtered_top_voters = top_6_voters[top_6_voters >= 0.8]
        filtered_similarity_df = similarity_df.loc[filtered_top_voters.index, filtered_top_voters.index].reset_index(drop=False)

        if selected:
            similarity_data = pd.DataFrame(filtered_similarity_df).reset_index(drop=False).rename(columns={voter: 'similarity'}).reset_index(drop=True)
        else:
            similarity_data = pd.DataFrame(filtered_similarity_df).reset_index(drop=False).rename(columns={fin_score['voter'].iloc[0]: 'similarity'}).reset_index(drop=True)
        all_score = in_score.merge(fin_score, how='left', on=['chain', 'voter', 'in_score']).sort_values(by='final_score', ascending=False).reset_index(drop=True)
        similar_vals = filtered_similarity_df[['voter']].merge(all_score, how='left', on='voter').reset_index(drop=True)
        similar_vals = similar_vals.merge(rank_data, how='left', on=['voter', 'final_score']).merge(similarity_data[['voter', 'similarity']], how='left', on=['voter'])
        similar_vals = similar_vals.to_json(orient='records')

        return similar_vals, 200

    except Exception as e:
        print(f"An error occurred: {e}")
        return jsonify({"error": "Internal Server Error"}), 500


@app.route('/getRaw', methods=['POST'])
def getRaw():
    try:
        data = request.get_json()
        chain = data['chain']
        weight = data['weight']
        inout_ratio = data['inout_ratio']

        participation = data['p_participation']
        passed = data['p_passed']
        match = data['p_match']
        missblock = data['missblock']
        jailed_ratio = data['jailed_ratio']
        asset_value = data['asset_value']
        delegator = data['delegator']
        rank = data['rank']
        commission = data['commission']
        day = data['day']

        ranges = {
            "p_participation": participation,
            "p_passed": passed,
            "p_matchproposal": match,
            "missblock": missblock,
            "jailed_ratio": jailed_ratio,
            "asset_value": asset_value,
            "delegator": delegator,
            "rank": rank,
            "commission": commission,
            "day": day
        }

        chain_data = valData[valData['chain'] == chain]
        voters = pd.DataFrame([v for v in chain_data['voter']]).rename(columns={0: 'voter'})
        val_data = valData[valData['voter'].isin(voters['voter'])]

        # 데이터 전처리
        in_data = pre_process(chain_data, ranges)
        out_data = pre_process(val_data, ranges)

        # 점수 계산
        in_score = cal_score(in_data, weight).rename(columns={'total_score': 'in_score'})
        out_score = cal_score(out_data, weight).merge(out_data[['chain', 'voter', 'proportion_av']], how='left', on=['chain', 'voter'])
        out_score['out_score'] = out_score['total_score']*out_score['proportion_av']
        out_score = out_score[['voter', 'out_score']].groupby('voter').sum().reset_index(drop=False)
        fin_score = cal_final_score(in_score, out_score, inout_ratio).sort_values(by='final_score', ascending=False).reset_index(drop=True)

        # 반환값 정리
        result_data = valData[valData['chain']==chain].merge(fin_score, how='left', on=['chain', 'voter'])
        result_data = result_data[['voter', 'final_score', 'token', 'rank', 'delegator', 'voting_power', 'p_participation', 'p_passed', 'p_matchproposal', 'missblock', 'jailed_ratio', 'commission', 'asset_value', 'day']]
        result_data = result_data.sort_values(by='final_score', ascending=False).reset_index(drop=True)
        result_data = result_data.to_json(orient='records')

        return result_data, 200

    except Exception as e:
        print(f"An error occurred: {e}")
        return jsonify({"error": "Internal Server Error"}), 500
    

@app.route('/timeSeriesData', methods=['POST'])
def timeSeriesData():
    try:
        data = request.get_json()

        chain, similars, check = data["chain"], data["similars"], data["check"]

        selected_chain = tsdf[tsdf['chain'] == chain]
        selected_chain['voter'] = pd.Categorical(selected_chain['voter'], categories=similars, ordered=True)

        selected_val = selected_chain[selected_chain['voter'].isin(similars)].sort_values(by='voter')
        selected_val = selected_val[['voter', check, 'record_time']]
        selected_val = selected_val.dropna(subset=[check]).reset_index(drop=True)
        
        json_str = selected_val.to_json(orient='records')
        return jsonify(json_str), 200
    
    except Exception as e:
        print(f"An error occurred: {e}")
        return jsonify({"error": "Internal Server Error"}), 500


if __name__ == '__main__':
    app.run(port=5002)
# Out:
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:18: DtypeWarning: Columns (3,5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   tsdf = pd.read_csv('./timeSeriesVal.csv').drop(columns=['Unnamed: 0'])
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5002
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:27] "OPTIONS /getHist HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:27] "OPTIONS /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:27] "OPTIONS /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:27] "OPTIONS /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:27] "OPTIONS /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:27] "OPTIONS /getHist HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:27] "OPTIONS /getSimilarity HTTP/1.1" 200 -
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['commission_mean'] = np.mean(df['commission'])
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:27] "OPTIONS /getSimilarInfo HTTP/1.1" 200 -
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: x * within_range(x, min_val, max_val, 0))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: x * within_range(x, min_val, max_val, 0))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: x * within_range(x, min_val, max_val, 0))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: x * within_range(x, min_val, max_val, max_val))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: x * within_range(x, min_val, max_val, 1))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: x * within_range(x, min_val, max_val, 0))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: x * within_range(x, min_val, max_val, 0))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: x * within_range(x, min_val, max_val, 0))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: x * within_range(x, min_val, max_val, 1))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: x * within_range(x, min_val, max_val, 0))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['commission_rank'] = df['commission'].rank(ascending=False)
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['missblock_scaled'] = scaler_0_1.fit_transform(df['missblock'].values.reshape(-1, 1)).flatten()
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['commission_variance_log'] = np.log1p(df['commission_variance'])
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['commission_variance_scaled'] = scaler_0_1.fit_transform(df['commission_variance_log'].values.reshape(-1, 1)).flatten()
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['asset_value_log'] = np.log1p(df['asset_value'])
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['asset_value_scaled'] = scaler_0_1.fit_transform(df['asset_value_log'].values.reshape(-1, 1)).flatten()
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['asset_variance_log'] = np.log1p(np.sqrt(df['asset_variance']))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['asset_variance_scaled'] = scaler_0_1.fit_transform(df['asset_variance_log'].values.reshape(-1, 1)).flatten()
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['delegator_log'] = np.log1p(df['delegator'])
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rank'] = df['rank'].apply(lambda x: max_rank if x == 0 else x)
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['commission_mean'] = np.mean(df['commission'])
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: x * within_range(x, min_val, max_val, 0))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: x * within_range(x, min_val, max_val, 0))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: x * within_range(x, min_val, max_val, 0))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: x * within_range(x, min_val, max_val, max_val))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: x * within_range(x, min_val, max_val, 1))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: x * within_range(x, min_val, max_val, 0))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: x * within_range(x, min_val, max_val, 0))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: x * within_range(x, min_val, max_val, 0))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: x * within_range(x, min_val, max_val, 1))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: x * within_range(x, min_val, max_val, 0))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['commission_mean'] = np.mean(df['commission'])
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: x * within_range(x, min_val, max_val, 0))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: x * within_range(x, min_val, max_val, 0))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: x * within_range(x, min_val, max_val, 0))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: x * within_range(x, min_val, max_val, max_val))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: x * within_range(x, min_val, max_val, 1))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: x * within_range(x, min_val, max_val, 0))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: x * within_range(x, min_val, max_val, 0))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: x * within_range(x, min_val, max_val, 0))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: x * within_range(x, min_val, max_val, 1))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: x * within_range(x, min_val, max_val, 0))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['commission_rank'] = df['commission'].rank(ascending=False)
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['missblock_scaled'] = scaler_0_1.fit_transform(df['missblock'].values.reshape(-1, 1)).flatten()
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['commission_variance_log'] = np.log1p(df['commission_variance'])
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['commission_variance_scaled'] = scaler_0_1.fit_transform(df['commission_variance_log'].values.reshape(-1, 1)).flatten()
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['asset_value_log'] = np.log1p(df['asset_value'])
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['asset_value_scaled'] = scaler_0_1.fit_transform(df['asset_value_log'].values.reshape(-1, 1)).flatten()
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['asset_variance_log'] = np.log1p(np.sqrt(df['asset_variance']))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['asset_variance_scaled'] = scaler_0_1.fit_transform(df['asset_variance_log'].values.reshape(-1, 1)).flatten()
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['delegator_log'] = np.log1p(df['delegator'])
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rank'] = df['rank'].apply(lambda x: max_rank if x == 0 else x)
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['commission_rank'] = df['commission'].rank(ascending=False)
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['missblock_scaled'] = scaler_0_1.fit_transform(df['missblock'].values.reshape(-1, 1)).flatten()
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['commission_mean'] = np.mean(df['commission'])
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: x * within_range(x, min_val, max_val, 0))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: x * within_range(x, min_val, max_val, 0))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: x * within_range(x, min_val, max_val, 0))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: x * within_range(x, min_val, max_val, max_val))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: x * within_range(x, min_val, max_val, 1))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: x * within_range(x, min_val, max_val, 0))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: x * within_range(x, min_val, max_val, 0))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: x * within_range(x, min_val, max_val, 0))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: x * within_range(x, min_val, max_val, 1))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: x * within_range(x, min_val, max_val, 0))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['commission_variance_log'] = np.log1p(df['commission_variance'])
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['commission_variance_scaled'] = scaler_0_1.fit_transform(df['commission_variance_log'].values.reshape(-1, 1)).flatten()
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['asset_value_log'] = np.log1p(df['asset_value'])
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['asset_value_scaled'] = scaler_0_1.fit_transform(df['asset_value_log'].values.reshape(-1, 1)).flatten()
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['commission_rank'] = df['commission'].rank(ascending=False)
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['missblock_scaled'] = scaler_0_1.fit_transform(df['missblock'].values.reshape(-1, 1)).flatten()
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['asset_variance_log'] = np.log1p(np.sqrt(df['asset_variance']))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['commission_variance_log'] = np.log1p(df['commission_variance'])
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['commission_variance_scaled'] = scaler_0_1.fit_transform(df['commission_variance_log'].values.reshape(-1, 1)).flatten()
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['asset_variance_scaled'] = scaler_0_1.fit_transform(df['asset_variance_log'].values.reshape(-1, 1)).flatten()
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['asset_value_log'] = np.log1p(df['asset_value'])
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['asset_value_scaled'] = scaler_0_1.fit_transform(df['asset_value_log'].values.reshape(-1, 1)).flatten()
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['asset_variance_log'] = np.log1p(np.sqrt(df['asset_variance']))
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['delegator_log'] = np.log1p(df['delegator'])
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rank'] = df['rank'].apply(lambda x: max_rank if x == 0 else x)
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   score['contribution_score'] = df['p_participation'] + df['p_passed'] + df['p_matchproposal']
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   score['contribution_score'] = scaler_0_100.fit_transform(score[['contribution_score']])
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   score['stability_score'] = df['asset_value_scaled'] * (1 - df['asset_variance_scaled']) - df['missblock_scaled'] - df['jailed_ratio'] - df['commission_variance_scaled']
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   score['stability_score'] = scaler_0_100.fit_transform(score[['stability_score']])
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   score['popularity_score'] = df['delegator_log'] + 1 / (df['rank'])
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:80: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   score['popularity_score'] = scaler_0_100.fit_transform(score[['popularity_score']])
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['asset_variance_scaled'] = scaler_0_1.fit_transform(df['asset_variance_log'].values.reshape(-1, 1)).flatten()
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   score['commission_score'] = 1 - (df['commission'] / df['commission_mean']) + (df['commission_rank'] / len(df) * 100)
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   score['commission_score'] = scaler_0_100.fit_transform(score[['commission_score']])
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:27] "OPTIONS /timeSeriesData HTTP/1.1" 200 -
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   score['period_score'] = df['day']
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   score['period_score'] = scaler_0_100.fit_transform(score[['period_score']])
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chainScore['contribution_score'] = chainScore['contribution_score'] * weight[0] / sum(weight)
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chainScore['stability_score'] = chainScore['stability_score'] * weight[1] / sum(weight)
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chainScore['popularity_score'] = chainScore['popularity_score'] * weight[2] / sum(weight)
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chainScore['commission_score'] = chainScore['commission_score'] * weight[3] / sum(weight)
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chainScore['period_score'] = chainScore['period_score'] * weight[4] / sum(weight)
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chainScore['total_score'] = chainScore['contribution_score'] + chainScore['stability_score'] + chainScore['popularity_score'] + chainScore['commission_score'] + chainScore['period_score']
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['delegator_log'] = np.log1p(df['delegator'])
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rank'] = df['rank'].apply(lambda x: max_rank if x == 0 else x)
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   score['contribution_score'] = df['p_participation'] + df['p_passed'] + df['p_matchproposal']
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   score['contribution_score'] = scaler_0_100.fit_transform(score[['contribution_score']])
# /var/folders/nc/dhlk15l910g4hrbcq92y1cy40000gn/T/ipykernel_1632/4137747082.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
#   df['commission_variance_log'] = np.log1p(df['commission_variance'])
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:32] "POST /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:32] "POST /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:32] "POST /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:32] "POST /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:32] "POST /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:33] "OPTIONS /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:33] "OPTIONS /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:33] "POST /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:33] "POST /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:33] "POST /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:33] "POST /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:33] "POST /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:33] "OPTIONS /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:34] "OPTIONS /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:34] "POST /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:34] "POST /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:34] "POST /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:34] "POST /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:35] "POST /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:35] "POST /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:35] "POST /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:35] "POST /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:35] "POST /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:36] "POST /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:36] "POST /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:36] "POST /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:36] "POST /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:44] "OPTIONS /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:44] "OPTIONS /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:44] "OPTIONS /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:44] "POST /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:44] "POST /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:44] "POST /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:44] "OPTIONS /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:44] "POST /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:46] "POST /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:46] "POST /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:46] "POST /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:46] "POST /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:47] "POST /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:47] "POST /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:47] "POST /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:48] "POST /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:56] "OPTIONS /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:56] "OPTIONS /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:56] "OPTIONS /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:56] "POST /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:56] "POST /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:56] "POST /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:56] "OPTIONS /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:57] "POST /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:57] "POST /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:57] "POST /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:57] "POST /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:58] "POST /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:59] "POST /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:59] "POST /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:59] "POST /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:42:59] "POST /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:00] "POST /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:00] "POST /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:00] "POST /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:00] "POST /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:01] "POST /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:01] "POST /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:01] "POST /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:02] "POST /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:03] "OPTIONS /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:03] "OPTIONS /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:03] "OPTIONS /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:03] "POST /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:03] "POST /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:03] "POST /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:03] "OPTIONS /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:03] "POST /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:04] "POST /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:04] "POST /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:04] "POST /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:04] "POST /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:05] "POST /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:05] "POST /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:05] "POST /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:06] "POST /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:08] "OPTIONS /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:08] "OPTIONS /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:08] "OPTIONS /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:08] "POST /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:08] "POST /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:08] "POST /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:08] "OPTIONS /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:09] "POST /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:12] "POST /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:12] "POST /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:12] "POST /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:12] "POST /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:23] "OPTIONS /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:23] "OPTIONS /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:23] "OPTIONS /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:23] "POST /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:23] "POST /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:23] "OPTIONS /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:23] "POST /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:23] "POST /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:25] "POST /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:25] "POST /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:25] "POST /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:25] "POST /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:26] "POST /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:26] "POST /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:26] "POST /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:26] "POST /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:27] "POST /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:27] "POST /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:27] "POST /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:27] "POST /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:28] "POST /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:28] "POST /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:28] "POST /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:28] "POST /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:29] "OPTIONS /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:29] "OPTIONS /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:29] "OPTIONS /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:29] "POST /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:29] "POST /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:29] "POST /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:29] "OPTIONS /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:30] "POST /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:30] "POST /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:30] "POST /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:30] "POST /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:31] "POST /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:31] "POST /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:31] "POST /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:31] "POST /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:32] "POST /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:32] "POST /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:32] "POST /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:32] "POST /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:33] "POST /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:33] "POST /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:33] "POST /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:33] "POST /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:34] "POST /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:34] "OPTIONS /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:34] "OPTIONS /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:34] "OPTIONS /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:34] "POST /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:34] "POST /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:34] "POST /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:34] "OPTIONS /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:35] "POST /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:35] "POST /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:35] "POST /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:35] "POST /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:36] "POST /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:36] "POST /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:36] "POST /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:36] "POST /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:37] "POST /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:37] "POST /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:37] "POST /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:37] "POST /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:38] "POST /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:39] "POST /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:39] "POST /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:39] "POST /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:39] "POST /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:40] "OPTIONS /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:40] "OPTIONS /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:40] "OPTIONS /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:40] "POST /getRaw HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:40] "POST /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:40] "POST /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:40] "OPTIONS /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:43:41] "POST /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:44:18] "OPTIONS /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:44:18] "OPTIONS /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:44:19] "POST /getSimilarity HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:44:19] "POST /getSimilarInfo HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:44:19] "OPTIONS /timeSeriesData HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [14/Aug/2024 14:44:19] "POST /timeSeriesData HTTP/1.1" 200 -
